# %% [markdown]
# ![Fixel Algorithms](https://fixelalgorithms.co/images/CCExt.png)

# %% [markdown]
# # <center> Optimization Methods </center>
# ## <center> Exercise 1 </center>
# ### <center> Gradient Descent and Momentum </center>

# %% [markdown]
# # 1. Theoretical Exercises

# %% [markdown]
# ### 1.1
# Let $f:\mathbb{R}^{d}\to\mathbb{R}$ and let $\boldsymbol{x}_{0}\in\mathbb{R}^{d}$.
#
# Prove that:
# $$
# \forall\boldsymbol{h}\in\mathbb{R}^{d}:\nabla f\left(\boldsymbol{x}_{0}\right)\left[\boldsymbol{h}\right]=\left\langle \boldsymbol{g}_{0},\boldsymbol{h}\right\rangle \implies\boldsymbol{g}_{0}=\nabla f\left(\boldsymbol{x}_{0}\right)
# $$
#
# <div class="alert alert-block alert-info">
# <span style="color:black">
#
# **Hints:**
# * Set $\boldsymbol{h}$ to be the standard basis.
# * What is the relation between partial derivative and the directional derivative?
# </span>
# </div>
#
#
# <div class="alert alert-block alert-success">
# <span style="color:black">
#
# **Your solution**<br>
# ...
#
# </span>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <span style="color:black">
#
# **Definition**
# $f:\mathbb{R}^{d_{1}}\to\mathbb{R}^{d_{2}}$ is said to be <u>linear</u> if:
# $$
# f\left(\alpha\boldsymbol{x}+\beta\boldsymbol{y}\right)=\alpha f\left(\boldsymbol{x}\right)+\beta f\left(\boldsymbol{y}\right)
# $$
# for all $\alpha,\beta\in\mathbb{R}$ and for all $\boldsymbol{x},\boldsymbol{y}\in\mathbb{R}^{d_{1}}$.
# </span>
# </div>
#
# ### 1.2
# Let $f:\mathbb{R}^{d_{1}}\to\mathbb{R}^{d_{2}}$ be a linear function.
#
# Prove that:
# $$\nabla f\left(\boldsymbol{x}\right)\left[\boldsymbol{h}\right]=f\left(\boldsymbol{h}\right)$$
# for all $\boldsymbol{x},\boldsymbol{h}\in\mathbb{R}^{d_{1}}$.
#
# <div class="alert alert-block alert-info">
# <span style="color:black">
#
# **Hint:** Use the definition of $\nabla f\left(\boldsymbol{x}\right)\left[\boldsymbol{h}\right]$.
# </span>
# </div>
#
# <div class="alert alert-block alert-success">
# <span style="color:black">
#
# **Your solution**<br>
# ...
#
# </span>
# </div>

# %% [markdown]
# ### 1.3 Computing some gradients
# Compute the directional derivative $\nabla f\left(\boldsymbol{x}\right)\left[\boldsymbol{h}\right]$ and the gradient $\nabla f\left(\boldsymbol{x}\right)$ of:
#
# #### 1.3.1
# $$f\left(\boldsymbol{x}\right)=\boldsymbol{x}^{T}\boldsymbol{A}\boldsymbol{x}$$
# <div class="alert alert-block alert-info">
# <span style="color:black">
#
# **Hints:**
# * $f\left(\boldsymbol{x}\right)=\boldsymbol{x}^{T}\boldsymbol{A}\boldsymbol{x}=\left\langle \boldsymbol{x},\boldsymbol{A}\boldsymbol{x}\right\rangle $
# * Use the product rule and Question 1.2
# * A useful tool: http://www.matrixcalculus.org/
# </span>
# </div>
# <div class="alert alert-block alert-success">
# <span style="color:black">
#
# **Your solution**<br>
# ...
#
# </span>
# </div>
#
# #### 1.3.2
# $$f\left(\boldsymbol{X}\right)=\text{Tr}\left\{ \boldsymbol{X}^{T}\boldsymbol{A}\boldsymbol{X}\right\} $$
# where $\boldsymbol{X}\in\mathbb{R}^{N\times d}$ and $\text{Tr}\left\{ \cdot\right\} $
# is the trace operator.
# <div class="alert alert-block alert-info">
# <span style="color:black">
#
# **Hints:**
# * $f\left(\boldsymbol{X}\right)=\text{Tr}\left\{ \boldsymbol{X}^{T}\boldsymbol{A}\boldsymbol{X}\right\} =\left\langle \boldsymbol{X},\boldsymbol{A}\boldsymbol{X}\right\rangle $
# * Use the product rule and Question 1.2
# </span>
# </div>
# <div class="alert alert-block alert-success">
# <span style="color:black">
#
# **Your solution**<br>
# ...
#
# </span>
# </div>
#
# #### 1.3.3
# $$f\left(\boldsymbol{x}\right)=\left\Vert \boldsymbol{y}-\boldsymbol{A}\boldsymbol{x}\right\Vert _{2}^{2}$$
# <div class="alert alert-block alert-info">
# <span style="color:black">
#
# **Hints:**
# * $f\left(\boldsymbol{x}\right)=\left\Vert \boldsymbol{y}-\boldsymbol{A}\boldsymbol{x}\right\Vert _{2}^{2}=\left\langle ?,?\right\rangle $
# * Use the product rule and Question 1.2
# </span>
# </div>
# <div class="alert alert-block alert-success">
# <span style="color:black">
#
# **Your solution**<br>
# ...
#
# </span>
# </div>
#
# #### 1.3.4
# $$f\left(\boldsymbol{X}\right)=\left\Vert \boldsymbol{Y}-\boldsymbol{A}\boldsymbol{X}\right\Vert _{F}^{2}$$
# where:
# * $\boldsymbol{Y}\in\mathbb{R}^{D\times N}$, $\boldsymbol{A}\in\mathbb{R}^{D\times d}$
# and $\boldsymbol{X}\in\mathbb{R}^{d\times N}$.
# * $\left\Vert \cdot\right\Vert _{F}^{2}$ is the Frobenius norm, that
# is, $\left\Vert \boldsymbol{X}\right\Vert _{F}^{2}=\left\langle \boldsymbol{X},\boldsymbol{X}\right\rangle =\text{Tr}\left\{ \boldsymbol{X}^{T}\boldsymbol{X}\right\} $.
#
# <div class="alert alert-block alert-info">
# <span style="color:black">
#
# **Hints:**
# * $f\left(\boldsymbol{X}\right)=\left\Vert \boldsymbol{Y}-\boldsymbol{A}\boldsymbol{X}\right\Vert _{F}^{2}=\left\langle ?,?\right\rangle $
# * Use the product rule and Question 1.2
# </span>
# </div>
# <div class="alert alert-block alert-success">
# <span style="color:black">
#
# **Your solution**<br>
# ...
#
# </span>
# </div>

# %% [markdown]
# ### 1.4 (Extra!) Computing some gradients - Part II
# <div class="alert alert-block alert-danger">
# <span style="color:black">
#
# **This part is a bit harder and you do not have to solve it.**
# </span>
# </div>
#
# Compute the directional derivative $\nabla f\left(\boldsymbol{x}\right)\left[\boldsymbol{h}\right]$ and the gradient $\nabla f\left(\boldsymbol{x}\right)$ of:
#
# #### 1.4.1
# $$f\left(\boldsymbol{X}\right)=\left\langle \boldsymbol{X}^{T}\boldsymbol{A},\boldsymbol{Y}^{T}\right\rangle $$
# where $\boldsymbol{Y}\in\mathbb{R}^{D\times N}$, $\boldsymbol{A}\in\mathbb{R}^{d\times D}$
# and $\boldsymbol{X}\in\mathbb{R}^{d\times N}$.
# <div class="alert alert-block alert-success">
# <span style="color:black">
#
# **Your solution**<br>
# ...
#
# </span>
# </div>
#
# #### 1.4.2
# $$f\left(\boldsymbol{x}\right)=\boldsymbol{a}^{T}g\left(\boldsymbol{x}\right)$$
# where:
# * $g:\mathbb{R}\to\mathbb{R}$ is scalar function (for example $g\left(x\right)=\sin\left(x\right)$)
# with a known derivative $g'$.
# * $g\left(\boldsymbol{x}\right):=\left[\begin{matrix}g\left(x_{1}\right)\\
# \vdots\\
# g\left(x_{d}\right)
# \end{matrix}\right]\in\mathbb{R}^{d}$
#
# <div class="alert alert-block alert-info">
# <span style="color:black">
#
# **Hints:**
# * $f\left(\boldsymbol{x}\right)=\boldsymbol{a}^{T}g\left(\boldsymbol{x}\right)=\left\langle \boldsymbol{x},g\left(\boldsymbol{x}\right)\right\rangle $
# * Show that $\nabla g\left(\boldsymbol{x}\right)\left[\boldsymbol{h}\right]=g'\left(\boldsymbol{x}\right)\circ\boldsymbol{h}$ where $\circ$ is the Hadamard product.
# </span>
# </div>
# <div class="alert alert-block alert-success">
# <span style="color:black">
#
# **Your solution**<br>
# ...
#
# </span>
# </div>
#
# #### 1.4.3
# $$f\left(\boldsymbol{X}\right)=\left\langle \boldsymbol{A},\log\left[\boldsymbol{X}\right]\right\rangle $$
# where:
# * $\boldsymbol{X}\in\mathbb{R}^{d\times d}$
# * $\log\left[\boldsymbol{X}\right]$ is an element-wise log, that is:
# $$\boldsymbol{M}=\log\left[\boldsymbol{X}\right]\implies\boldsymbol{M}\left[i,j\right]=\log\left(\boldsymbol{X}\left[i,j\right]\right)$$
#
# <div class="alert alert-block alert-info">
# <span style="color:black">
#
# **Hint:** Use Question 1.4.2
#
# </span>
# </div>
# <div class="alert alert-block alert-success">
# <span style="color:black">
#
# **Your solution**<br>
# ...
#
# </span>
# </div>
#
# #### 1.4.4
# $$f\left(\boldsymbol{X}\right)=\left\langle \boldsymbol{a},\text{diag}\left(\boldsymbol{X}\right)\right\rangle $$
# where:
# * $\boldsymbol{X}\in\mathbb{R}^{d\times d}$
# * $\text{diag}:\mathbb{R}^{d\times d}\to\mathbb{R}^{d}$ returns the
# diagonal of a matrix, that is:
# $$\boldsymbol{b}=\text{diag}\left(\boldsymbol{X}\right)\implies\boldsymbol{b}\left[i\right]=\boldsymbol{X}\left[i,i\right]$$
#
# <div class="alert alert-block alert-info">
# <span style="color:black">
#
# **Hint:** Is this true?
# $$\left\langle \boldsymbol{a},\text{diag}\left(\boldsymbol{X}\right)\right\rangle \overset{?}{=}\left\langle \text{diag}\left(\boldsymbol{a}\right),\boldsymbol{X}\right\rangle $$
# </span>
# </div>
# <div class="alert alert-block alert-success">
# <span style="color:black">
#
# **Your solution**<br>
# ...
#
# </span>
# </div>

# %% [markdown]
# # 2. Coding

# %%
import numpy             as np
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rc('font', **{'size' : 16})

# %% [markdown]
# ## Gradient descent
# * Let $\boldsymbol{Y}\in\mathbb{R}^{d\times d}$ be a blurred version
# of the image $\boldsymbol{X}\in\mathbb{R}^{d\times d}$:
# $$\boldsymbol{Y}=\boldsymbol{H}\boldsymbol{X}\boldsymbol{H}^{T}$$
# where $\boldsymbol{H}\in\mathbb{R}^{d\times d}$ is a known (separable)
# blurring matrix.

# %% [markdown]
# #### Load the data ($\boldsymbol{Y}$ and $\boldsymbol{H}$):

# %%
from scipy.io import loadmat

data = loadmat('data.mat')
mY   = data['Y']
mH   = data['H']

mY.shape, mH.shape
# Out:
# ((256, 256), (256, 256))

# %% [markdown]
# #### Plot $Y$ and $H$:

# %%
_, ax = plt.subplots(1, 2, figsize=(12, 6))
ax[0].imshow   (mY, cmap='gray')
ax[1].matshow  (mH)
ax[0].set_title('$Y = H X H^T$')
ax[1].set_title('$H$')
plt.show()

# %% [markdown]
# * Our goal is to find $\boldsymbol{X}$ that minimizes:
# $$\boldsymbol{X}^{\star}=\arg\min_{\boldsymbol{X}}f\left(\boldsymbol{X}\right)=\arg\min_{\boldsymbol{X}}\left\Vert \boldsymbol{Y}-\boldsymbol{H}\boldsymbol{X}\boldsymbol{H}^{T}\right\Vert _{F}^{2}$$

# %% [markdown]
# ### 2.1
# 1. Find a closed form expression for $\boldsymbol{X}^{\star}$ as a function of $\boldsymbol{Y}$ and $\boldsymbol{H}$.
# 2. Compute $\boldsymbol{X}^{\star}$ and plot it.

# %% [markdown]
# 1.

# %% [markdown]
# $$\mathbf{X}^{*}=\mathbf{H}^{-1}\mathbf{Y}(\mathbf{H}^{-1})^{T}$$

# %% [markdown]
# 2.

# %%
import numpy as np

mInvH = np.linalg.inv(mH) # compute the inverse once
mXstar = mInvH @ mY @ mInvH.T # use twice

_, ax = plt.subplots(1, 2, figsize=(12, 6))
ax[0].imshow   (mY,     cmap='gray')
ax[1].imshow   (mXstar, cmap='gray')
ax[0].set_title('$Y = H X H^T$')
ax[1].set_title('$X^{\star}$')
plt.show()

# %%
# https://towardsdatascience.com/basics-of-gifs-with-pythons-matplotlib-54dd544b6f30

import os
import numpy as np
import matplotlib.pyplot as plt
import imageio

# https://www.programcreek.com/python/example/102363/matplotlib.pyplot.imsave
plt.imsave("test.png", mXstar, cmap='gray')

# %% [markdown]
# ------------------------------------------------------------------------------------------------------
# * To avoid matrix inversion, we will find $\boldsymbol{X}^{\star}$ using gradient descent.
# ### 2.2
# 1. Implement the following functions **(in the cell below)** where
# $$f\left(\boldsymbol{X}\right)=\left\Vert \boldsymbol{Y}-\boldsymbol{H}\boldsymbol{X}\boldsymbol{H}^{T}\right\Vert _{F}^{2}$$
#
# ```python
# #==================================================#
# def f(X):
# #==================================================#
# def Df(X):
# #==================================================#
# def ApplyGradientDescent(f, Df, X0, lr, ε):
# #==================================================#
# ```
#
# 2. Set a reasonable starting point $\boldsymbol{X}^{\left(0\right)}$.
# 3. Find $\boldsymbol{X}$ such that $f\left(\boldsymbol{X}\right)<\epsilon$ where $\epsilon=10^{-4}$.
#     * Time your function.
#     * Plot the final obtained $\boldsymbol{X}$.

# %% [markdown]
# $$-2\mathbf{H}^{T}(\mathbf{Y}-\mathbf{H}\mathbf{X}\mathbf{H}^{T})\mathbf{H} $$

# %%
'''
Your code here...
'''
#==================================================#
def f(X):
    '''
    f(X) = ||Y - HXH^T||_F^2 is the objective function
    '''

    # calculate the Frobenius norm
    # https://numpy.org/doc/stable/reference/generated/numpy.linalg.norm.html
    norm = np.linalg.norm(mY - mH @ X @ mH.T)
    
    return ( norm ** 2)
#==================================================#
#==================================================#
def Df(X):
    '''
    Df(X) = ∇f(X) is the objective gradient
    '''
    # norm2(Y-H*X*H')^2
    # 
    return -2*mH.T@(mY-mH@X@mH.T)@mH
#==================================================#
#==================================================#
def ApplyGradientDescent(f, Df, X0, lr, ε):
    vFXt = []
    Xt = X0.copy()
    while True:
        fxt = f(Xt)
        vFXt.append(fxt)
        if fxt < ε:
            break
        Xt -= lr*Df(Xt)
    return Xt, vFXt
    '''
    Apply gradient descent.
    Args:
        f  - Objective function
        Df - Objective gradient
        X0 - Initial point
        lr - Learning rate (step size)
        ε  - Stopping criterion value
    Output:
        X  - The converged X
    Stopping criterion:
        Stop iterate when f(X) < ε
    '''
    # https://towardsdatascience.com/gradient-descent-in-python-a0d07285742f

#==================================================#

# %%
import timeit

ε = 0.1
lr = 0.05

start = timeit.default_timer()
mXGD, vfxt = ApplyGradientDescent(f, Df, mY, lr, ε)
stop = timeit.default_timer()

print('ApplyGradientDescent: ', stop - start)
# Out:
# ApplyGradientDescent:  5.545908300000519

# %%
vfxt
# Out:
# [33.249415732451254,
#  30.442746740469612,
#  27.951741894661644,
#  25.73574632998824,
#  23.759772111503292,
#  21.99366647371274,
#  20.41140664694691,
#  18.9905014807005,
#  17.71148323269468,
#  16.557475538588527,
#  15.513825795144944,
#  14.567792049536468,
#  13.708276047985194,
#  12.925595406976123,
#  12.211288970683231,
#  11.55795034308436,
#  10.95908536098274,
#  10.408989928588877,
#  9.902645185335697,
#  9.43562744283698,
#  9.004030718273986,
#  8.604400021660993,
#  8.233673833158182,
#  7.889134442048376,
#  7.568365018030662,
#  7.269212453860484,
#  6.98975516091079,
#  6.728275119995068,
#  6.4832335921874,
#  6.253249981259532,
#  6.037083413138677,
#  5.833616660499106,
#  5.641842093942091,
#  5.460849386630361,
#  5.289814737937608,
#  5.12799141467296,
#  4.974701436608987,
#  4.82932825710812,
#  4.691310310223769,
#  4.560135313269639,
#  4.4353352289457515,
#  4.316481804055945,
#  4.20318261296636,
#  4.095077543506206,
#  3.9918356712293654,
#  3.89315247503184,
#  3.798747353220623,
#  3.7083614043943345,
#  3.6217554420446105,
#  3.5387082157212673,
#  3.459014815010662,
#  3.3824852355293937,
#  3.308943088698086,
#  3.2382244392862245,
#  3.1701767566556502,
#  3.1046579673166517,
#  3.041535597880931,
#  2.9806859987791445,
#  2.921993640232313,
#  2.8653504729477746,
#  2.8106553468700817,
#  2.757813482071206,
#  2.7067359865265983,
#  2.6573394161057236,
#  2.609545372618141,
#  2.563280136207765,
#  2.5184743287864197,
#  2.4750626055498492,
#  2.4329833719306477,
#  2.392178523618348,
#  2.35259320752134,
#  2.314175601762293,
#  2.27687671299159,
#  2.2406501894748754,
#  2.2054521485636434,
#  2.1712410172941112,
#  0.10191510991707188,
#  0.10179051545171472,
#  0.10166620704849298,
#  0.1015421837440064,
#  0.10141844457910545,
#  0.10129498859886872,
#  0.10117181485258021,
#  0.10104892239370618,
#  0.10092631027987273,
#  0.10080397757284297,
#  0.10068192333849527,
#  0.1005601466468004,
#  0.10043864657179977,
#  0.10031742219158377,
#  0.10019647258826936,
#  0.10007579684797913,
#  0.09995539406081903]

# %%
_, ax = plt.subplots(1, 3, figsize=(18, 8))
ax[0].imshow   (mY,     cmap='gray')
ax[1].imshow   (mXstar, cmap='gray')
ax[2].imshow   (mXGD, cmap='gray')  
ax[0].set_title('$Y = H X H^T$')
ax[1].set_title('$X^{\star}$')
ax[2].set_title('$X^{GD}$')
plt.show()

# %% [markdown]
# ### Momentum
# <div class="alert alert-block alert-warning">
# <span style="color:black">
#
# * <ins>Momentum</ins> is an effective method to improve convergence rate.
# * Gradient descent update rule:
# $$\boldsymbol{x}^{\left(t\right)}=\boldsymbol{x}^{\left(t-1\right)}-\mu\nabla f\left(\boldsymbol{x}^{\left(t-1\right)}\right)$$
# * Momentum update rule:
# $$\boldsymbol{x}^{\left(t\right)}=\boldsymbol{x}^{\left(t-1\right)}-\mu\nabla f\left(\boldsymbol{x}^{\left(t-1\right)}\right)+\beta\left(\boldsymbol{x}^{\left(t-1\right)}-\boldsymbol{x}^{\left(t-2\right)}\right)$$
# where $\beta\in[0,1)$ and typically $0.9\leq\beta\leq0.99$.
#
# </span>
# </div>

# %% [markdown]
# ### 2.3
# 1. Implement the following function:
#
# ```python
# #==================================================#
# def ApplyGradientDescentMomentum(f, Df, X0, lr, β, ε):
# #==================================================#
# ```
#
# 2. Set (the same) reasonable starting point $\boldsymbol{X}^{\left(0\right)}$.
# 3. Find $\boldsymbol{X}$ such that $f\left(\boldsymbol{X}\right)<\epsilon$ where $\epsilon=10^{-4}$.
#     * Time your function.
#     * Plot the final obtained $\boldsymbol{X}$.
#     * Compare the run-time performance with and without momentum.
#       (play with the hyper-parameters).
#         * **Bonus:**
#             Plot the objective value $f(\boldsymbol{X})$ as a function of the iterations.
#             You may need to slightly modify your code.

# %%
'''
Your code here...
'''
max_iter = 5000

def ApplyGradientDescentMomentum(f, Df, X0, lr, β, ε):
    vFXt = []
    Xt = X0.copy()
    i = 0
    change = 0.0
    while True:
        fxt = f(Xt)
        vFXt.append(fxt)

        if fxt < ε:
            break
        if i > max_iter:
            break;

        gradient = Df(Xt)
        new_change = lr * gradient + β * change
        Xt = Xt - new_change
        change = new_change
        i = i + 1

    return Xt, vFXt

# %%
vMomentum = np.arange(0.9,1.0,0.01)

# %%
'''
Your code here...
'''

# https://stackoverflow.com/questions/5622976/how-do-you-calculate-program-run-time-in-python

import pandas as pd
momentum_dict = {}
momentum_time = {}

ε = 0.1

for momentum in vMomentum:
    start = timeit.default_timer()
    mXGDMomentum, vFXt = ApplyGradientDescentMomentum(f, Df, mY, lr, momentum, ε)
    stop = timeit.default_timer()

    time_elapsed = stop - start
    momentum_dict[f'{momentum:.2f}'] = vFXt
    momentum_time[f'{momentum:.2f}'] = time_elapsed
    print(f'GradientDescentMomentum with momentum {momentum:.2f}', stop - start)
# Out:
# GradientDescentMomentum with momentum 0.90 0.7606541000004654
# GradientDescentMomentum with momentum 0.91 0.5449239000008674
# GradientDescentMomentum with momentum 0.92 0.6316533999997773
# GradientDescentMomentum with momentum 0.93 0.4783738000005542
# GradientDescentMomentum with momentum 0.94 0.5077954000007594
# GradientDescentMomentum with momentum 0.95 0.5710299000002124
# GradientDescentMomentum with momentum 0.96 0.6759046999995917
# GradientDescentMomentum with momentum 0.97 0.9377231999987998
# GradientDescentMomentum with momentum 0.98 1.3089495000003808
# GradientDescentMomentum with momentum 0.99 3.2105144999986805

# %%
sns.lineplot(data=momentum_dict)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(15,5))

ax.set_title('Log-Likelihood')
ax.plot(*zip(*momentum_dict.items()), '-o')

momentum_dict.plot()
# Out:
# c:\Courses\Python_for_AI_Engineer\ML\Optimization_1_3\Ex1\.venv\lib\site-packages\numpy\core\shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22760/3045652510.py in <module>
#       2
#       3 ax.set_title('Log-Likelihood')
# ----> 4 ax.plot(*zip(*momentum_dict.items()), '-o')
#       5
#       6 momentum_dict.plot()
#
# c:\Courses\Python_for_AI_Engineer\ML\Optimization_1_3\Ex1\.venv\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
# -> 1607             self.add_line(line)
#    1608         self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1609         return lines
#
# c:\Courses\Python_for_AI_Engineer\ML\Optimization_1_3\Ex1\.venv\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    2099             line.set_clip_path(self.patch)
#    2100
# -> 2101         self._update_line_limits(line)
#    2102         if not line.get_label():
#    2103             line.set_label('_line%d' % len(self.lines))
#
# c:\Courses\Python_for_AI_Engineer\ML\Optimization_1_3\Ex1\.venv\lib\site-packages\matplotlib\axes\_base.py in _update_line_limits(self, line)
#    2121         Figures out the data limit of the given line, updating self.dataLim.
#    2122         """
# -> 2123         path = line.get_path()
#    2124         if path.vertices.size == 0:
#    2125             return
#
# c:\Courses\Python_for_AI_Engineer\ML\Optimization_1_3\Ex1\.venv\lib\site-packages\matplotlib\lines.py in get_path(self)
#    1020         """
#    1021         if self._invalidy or self._invalidx:
# -> 1022             self.recache()
#    1023         return self._path
#    1024
#
# c:\Courses\Python_for_AI_Engineer\ML\Optimization_1_3\Ex1\.venv\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     666         if always or self._invalidy:
#     667             yconv = self.convert_yunits(self._yorig)
# --> 668             y = _to_unmasked_float_array(yconv).ravel()
#     669         else:
#     670             y = self._y
#
# c:\Courses\Python_for_AI_Engineer\ML\Optimization_1_3\Ex1\.venv\lib\site-packages\matplotlib\cbook\__init__.py in _to_unmasked_float_array(x)
#    1331         return np.ma.asarray(x, float).filled(np.nan)
#    1332     else:
# -> 1333         return np.asarray(x, float)
#    1334
#    1335
#
# ValueError: setting an array element with a sequence.

# %%
import seaborn as sns

from matplotlib.pyplot import figure

f, ax = plt.subplots(figsize=(15, 6))
ax.set(xscale = "log", yscale="log")
sns.lineplot(data = vfxt, label="GD", ax = ax)
sns.lineplot(data = momentum_dict, ax = ax)
# Out:
# c:\Courses\Python_for_AI_Engineer\ML\Optimization_1_3\Ex1\.venv\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\Courses\Python_for_AI_Engineer\ML\Optimization_1_3\Ex1\.venv\lib\site-packages\pandas\core\arraylike.py:364: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# <AxesSubplot:>

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
ax1.set_title('f(xt)')
ax1.set_ylabel('linear')
ax1.set_xlabel('iterations')
ax1.set_yscale('linear')
ax1.plot(momentum_dict['0.90'])

ax2.set_title('f(xt)')
ax2.set_ylabel('log')
ax2.set_xlabel('iterations')
ax2.set_yscale('log')
ax2.plot(momentum_dict['0.90'])

# %%
_, ax = plt.subplots(1, 3, figsize=(18, 8))
ax[0].imshow   (mY,     cmap='gray')
ax[1].imshow   (mXstar, cmap='gray')
ax[2].imshow   (mXGDMomentum, cmap='gray')  
ax[0].set_title('$Y = H X H^T$')
ax[1].set_title('$X^{\star}$')
ax[2].set_title('$X^{GDMomentum}$')
plt.show()
